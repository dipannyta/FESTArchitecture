# %%
import os, sys
import numpy as np
import keras
from keras.utils import to_categorical
from keras.preprocessing import image
import pandas as pd

# %%
home_path= r'C:\Users\DIPANNYTA\Desktop\HAR_IMG\MHEALTH_IMG112\classified_data'
# Create main directory
train_path = os.path.join(home_path,'train')
os.mkdir(train_path)

# %%
for i in range(1,14):
    # Create sub-directories
    train_path_sub= os.path.join(home_path + r'/train',str(i))
    os.mkdir(train_path_sub)

# %%
# importing pandas
import pandas as pd
# Import the imsave and imread functions from the skimage.io module
from skimage.io import imsave, imread

# read text file into pandas DataFrame and create 
# header with names
df = pd.read_csv(r"C:\Users\DIPANNYTA\Desktop\HAR_IMG\mhealth_y.csv" , sep=" ", header=None, 
				names=["Label"])

# %%
df.head()
# Out:
#    Label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
# Read Text Files with Pandas using read_csv()


for i in range(0,7453):
    if(df.iat[i,0]==0):
        
        # Read the image file with the specified file path
        img1 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/1/"+str(i)+".png", img1)
    elif(df.iat[i,0]==1):
        
        # Read the image file with the specified file path
        img2 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/2/"+str(i)+".png", img2)
    elif(df.iat[i,0]==2):
        
        # Read the image file with the specified file path
        img3 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/3/"+str(i)+".png", img3)
    elif(df.iat[i,0]==3):
        
        # Read the image file with the specified file path
        img4 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/4/"+str(i)+".png", img4)
    elif(df.iat[i,0]==4):
        
        # Read the image file with the specified file path
        img5 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/5/"+str(i)+".png", img5)
    elif(df.iat[i,0]==5):
        
        # Read the image file with the specified file path
        img6 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/6/"+str(i)+".png", img6)
    elif(df.iat[i,0]==6):
        
        # Read the image file with the specified file path
        img7 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/7/"+str(i)+".png", img7)
    elif(df.iat[i,0]==7):
        
        # Read the image file with the specified file path
        img8 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/8/"+str(i)+".png", img8)
    elif(df.iat[i,0]==8):
        
        # Read the image file with the specified file path
        img9 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/9/"+str(i)+".png", img9)
    elif(df.iat[i,0]==9):
        
        # Read the image file with the specified file path
        img10 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/10/"+str(i)+".png", img10)
    elif(df.iat[i,0]==10):
        
        # Read the image file with the specified file path
        img11 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/11/"+str(i)+".png", img11)
    elif(df.iat[i,0]==11):
        
        # Read the image file with the specified file path
        img12 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/12/"+str(i)+".png", img12)
    elif(df.iat[i,0]==12):
        
        # Read the image file with the specified file path
        img13 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/MHEALTH_IMG112/classified_data/train/13/"+str(i)+".png", img13)
    else:
        print("Invalid")
