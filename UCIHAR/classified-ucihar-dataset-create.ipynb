# %%
import os, sys
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from tqdm import tqdm

# %%
home_path= r'C:\Users\DIPANNYTA\Desktop\HAR_IMG\TRAIN_IMG90\classified_data'
# Create main directory
train_path = os.path.join(home_path,'train')
os.mkdir(train_path)

# %%
for i in range(1,7):
    # Create sub-directories
    train_path_sub= os.path.join(home_path + r'/train',str(i))
    os.mkdir(train_path_sub)

# %%
# Read Text Files with Pandas using read_csv()

# importing pandas
import pandas as pd
# Import the imsave and imread functions from the skimage.io module
from skimage.io import imsave, imread

# read text file into pandas DataFrame and create 
# header with names
df = pd.read_csv(r"C:\Users\DIPANNYTA\Desktop\HAR_IMG\y_train.txt" , sep=" ", header=None, 
				names=["Label"])
for i in range(0,7352):
    if(df.iat[i,0]==1):
        print("Walking")
        # Read the image file with the specified file path
        img1 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/classified_data/train/1/"+str(i)+".png", img1)
    elif(df.iat[i,0]==2):
        print("WalkingUpstairs")
        # Read the image file with the specified file path
        img2 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/classified_data/train/2/"+str(i)+".png", img2)
    elif(df.iat[i,0]==3):
        print("WalkingDownstairs")
        # Read the image file with the specified file path
        img3 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/classified_data/train/3/"+str(i)+".png", img3)
    elif(df.iat[i,0]==4):
        print("Sitting")
        # Read the image file with the specified file path
        img4 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/classified_data/train/4/"+str(i)+".png", img4)
    elif(df.iat[i,0]==5):
        print("Standing")
        # Read the image file with the specified file path
        img5 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/classified_data/train/5/"+str(i)+".png", img5)
    elif(df.iat[i,0]==6):
        print("Laying")
        # Read the image file with the specified file path
        img6 = imread("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/"+str(i)+".png")
        # Save the image to disk with the specified file name
        imsave("C:/Users/DIPANNYTA/Desktop/HAR_IMG/TRAIN_IMG90/classified_data/train/6/"+str(i)+".png", img6)
    else:
        print("Invalid")
# Out:
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Standing
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Sitting
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Laying
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# Walking
# ...
